# %%
import rdkit
from rdkit.Chem import PandasTools
import pandas as pd
print('rdkit', rdkit.__version__)
print('pandas', pd.__version__)
# Out:
# rdkit 2020.03.2
# pandas 1.0.3

# %%
antibiotics = pd.DataFrame(columns=['Name','Smiles'])
antibiotics = antibiotics.append({'Smiles':'CC1(C(N2C(S1)C(C2=O)NC(=O)CC3=CC=CC=C3)C(=O)O)C',
  'Name':'Penicilline G'}, ignore_index=True)#Penicilline G
PandasTools.AddMoleculeColumnToFrame(antibiotics,'Smiles','Molecule',includeFingerprints=True)
antibiotics
# Out:
#             Name                                           Smiles  \
# 0  Penicilline G  CC1(C(N2C(S1)C(C2=O)NC(=O)CC3=CC=CC=C3)C(=O)O)C
#
#                                             Molecule
# 0  <img data-content="rdkit/molecule" src="data:i...

# %%
pkl = '/tmp/rdkit_example.pkl'
antibiotics.to_pickle(pkl)

# %% [markdown]
# # Restart Ipython Kernel

# %%
import rdkit
from rdkit.Chem import PandasTools
import pandas as pd

# %%
pkl = '/tmp/rdkit_example.pkl'
df = pd.read_pickle(pkl)
print('NumAtoms:', df.Molecule[0].GetNumAtoms())
df.Molecule[0]
# Out:
# NumAtoms: 23

# %%
df
# Out:
#             Name                                           Smiles  \
# 0  Penicilline G  CC1(C(N2C(S1)C(C2=O)NC(=O)CC3=CC=CC=C3)C(=O)O)C
#
#                                             Molecule
# 0  <img data-content="rdkit/molecule" src="data:i...

# %%
PandasTools.RenderImagesInAllDataFrames(images=True)
print('NumAtoms:', df.Molecule[0].GetNumAtoms())
df
# Out:
# NumAtoms: 23
#             Name                                           Smiles  \
# 0  Penicilline G  CC1(C(N2C(S1)C(C2=O)NC(=O)CC3=CC=CC=C3)C(=O)O)C
#
#                                             Molecule
# 0  <img data-content="rdkit/molecule" src="data:i...
